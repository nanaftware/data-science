# %% [markdown]
# # Regresión Lineal I

# %% [markdown]
# En este notebook intentaremos predecir cuántas veces será compartido en Redes Sociales un artículo de Machine Learning según algunas de sus características.
#
# **Recuerda guardar una copia de este notebook en tu drive si estás trabajando en ambiente cloud con Google Colaboratory**

# %% [markdown]
# ## Importar las librerías

# %% [markdown]
# Antes de empezar vamos a importar las siguientes librerías:
#
# *   Numpy
# *   Pandas
# *   Seaborn
# *   Matplotlib
# *   Scikit Learn

# %%
# Importa las librerías a nuestro entorno de trabajo
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## Cargar un archivo de datos
# Hay varias maneras de cargar un archivo de datos en nuestro entorno. El archivo lo podemos llamar desde una URL, desde una carpeta de nuestro drive o tener guardado de forma local en nuestra computadora.
#
# En este caso subiremos un primer archivo en forma local ejecutando lo siguiente:
#
# (el profesor te facilitará los archivos)

# %%
#cargamos los datos de entrada
#from google.colab import files
#uploaded = files.upload()
#for fn in uploaded.keys():
#    name=fn
data = pd.read_csv("C:/Personal/Docencia/Introducción al machine learning 2024/articulos_ml.csv", sep=",")

# %% [markdown]
# ## Análisis Exploratorio
#
# Realicemos un análisis exploratorio de los datos cargados en el dataframe.

# %%
#veamos cuantas dimensiones y registros contiene
data.shape
# Out:
# (161, 8)

# %%
#son 161 registros con 8 columnas. Veamos los primeros registros para tener una idea
data.head(10)
# Out:
#                                                Title  \
# 0  What is Machine Learning and how do we use it ...
# 1   10 Companies Using Machine Learning in Cool Ways
# 2  How Artificial Intelligence Is Revolutionizing...
# 3  Dbrain and the Blockchain of Artificial Intell...
# 4  Nasa finds entire solar system filled with eig...
# 5  5 ways Data Science and Machine Learning impac...
# 6  200 universities just launched 600 free online...
# 7  How Machine Learning can help Cryptocurrency T...
# 8  Tech companies should stop pretending AI won’t...
# 9  Artificial intelligence is going to completely...
#
#                                                  url  Word count  # of Links  \
# 0  https://blog.signals.network/what-is-machine-l...        1888           1
# 1                                                NaN        1742           9
# 2                                                NaN         962           6
# 3                                                NaN        1221           3
# 4                                                NaN        2039           1
# 5                                                NaN         761           0
# 6  https://qz.com/1120344/200-universities-just-l...        6462         600
# 7  https://cryptovest.com/news/how-machine-learni...         753           3
# 8  https://www.technologyreview.com/s/610298/tech...        1118           2
# 9                                                NaN        1581           4
#
#    # of comments  # Images video  Elapsed days  # Shares
# 0            2.0               2            34    200000
# 1            NaN               9             5     25000
# 2            0.0               1            10     42000
# 3            NaN               2            68    200000
# 4          104.0               4           131    200000
# 5            NaN               1            14     21000
# 6           28.0               2           170    200000
# 7            0.0               1            78     77000
# 8            NaN               1            62     59400
# 9            NaN               2            60     35000

# %% [markdown]
# ## ¿Qué observaciones puedes realizar de los datos?

# %%
# Ahora veamos algunas estadísticas de nuestros datos
data.describe()
# Out:
#         Word count  # of Links  # of comments  # Images video  Elapsed days  \
# count   161.000000  161.000000     129.000000      161.000000    161.000000
# mean   1808.260870    9.739130       8.782946        3.670807     98.124224
# std    1141.919385   47.271625      13.142822        3.418290    114.337535
# min     250.000000    0.000000       0.000000        1.000000      1.000000
# 25%     990.000000    3.000000       2.000000        1.000000     31.000000
# 50%    1674.000000    5.000000       6.000000        3.000000     62.000000
# 75%    2369.000000    7.000000      12.000000        5.000000    124.000000
# max    8401.000000  600.000000     104.000000       22.000000   1002.000000
#
#             # Shares
# count     161.000000
# mean    27948.347826
# std     43408.006839
# min         0.000000
# 25%      2800.000000
# 50%     16458.000000
# 75%     35691.000000
# max    350000.000000

# %% [markdown]
# Escribe tu análisis aquí

# %% [markdown]
# ## ¿Qué observaciones puedes indicar de estas estadísticas?
#
# ¿Cuál es la media de la Cantidad de palabras?
#
# ¿Cuales son los artículos más pequeños y los más grandes? (en cantidad de palabras)

# %% [markdown]
# ## Visualizamos Cantidad de Palabras vs. Compartidos
#
# Para esto graficaremos en dos dimensiones las variables indicadas.
#
# Así, visualizaremos una variable con color naranja y otra con color azul.

# %%
#Visualizar los datos de entrada
colores=['orange','blue']
tamanios=[30,60]

f1 = data['Word count'].values
f2 = data['# Shares'].values

# Vamos a pintar en 2 colores los puntos por debajo de la media de Cantidad de Palabras
asignar=[]
for index, row in data.iterrows():
    if(row['Word count']>1808):
        asignar.append(colores[0])
    else:
        asignar.append(colores[1])
    
plt.scatter(f1, f2, c=asignar, s=tamanios[0])
plt.show()

# %%
# Vamos a RECORTAR los datos en la zona donde se concentran más los puntos
# esto es en el eje X: entre 0 y 3.500
# y en el eje Y: entre 0 y 80.000
filtered_data = data[(data['Word count'] <= 3500) & (data['# Shares'] <= 80000)]

f1 = filtered_data['Word count'].values
f2 = filtered_data['# Shares'].values

# Vamos a pintar en colores los puntos por debajo y por encima de la media de Cantidad de Palabras
asignar=[]
for index, row in filtered_data.iterrows():
    if(row['Word count']>1808):
        asignar.append(colores[0])
    else:
        asignar.append(colores[1])
    
plt.scatter(f1, f2, c=asignar, s=tamanios[0])
plt.show()

# %%
# Veamos como cambian los valores una vez filtrados
filtered_data.describe()
# Out:
#         Word count  # of Links  # of comments  # Images video  Elapsed days  \
# count   148.000000  148.000000     121.000000      148.000000    148.000000
# mean   1640.209459    5.743243       7.256198        3.331081     91.554054
# std     821.975365    6.064418       6.346297        2.706476     91.143923
# min     250.000000    0.000000       0.000000        1.000000      1.000000
# 25%     971.000000    3.000000       2.000000        1.000000     28.750000
# 50%    1536.000000    5.000000       6.000000        3.000000     60.000000
# 75%    2335.750000    7.000000      11.000000        4.000000    110.500000
# max    3485.000000   49.000000      30.000000       22.000000    349.000000
#
#            # Shares
# count    148.000000
# mean   20545.648649
# std    19933.865031
# min        0.000000
# 25%     2750.000000
# 50%    15836.000000
# 75%    34177.500000
# max    77000.000000

# %% [markdown]
# ## Regresión Lineal Simple (1 variable)

# %% [markdown]
# Vamos a intentar primero una Regresión Lineal con 1 sóla variable

# %%
# Asignamos nuestra variable de entrada X para entrenamiento y las etiquetas Y.
dataX =filtered_data[["Word count"]]
X_train = np.array(dataX)
y_train = filtered_data['# Shares'].values

# %%
# Creamos el objeto de Regresión Linear
regr = linear_model.LinearRegression()

# Entrenamos nuestro modelo
regr.fit(X_train, y_train)

# Hacemos las predicciones que en definitiva una línea (en este caso, al ser 2D)
y_pred = regr.predict(X_train)

# Veamos los coeficienetes obtenidos, En nuestro caso, serán la Tangente
print('Coefficients: \n', regr.coef_)
# Este es el valor donde corta el eje Y (en X=0)
print('Independent term: \n', regr.intercept_)
# Error Cuadrado Medio
print("Mean squared error: %.2f" % mean_squared_error(y_train, y_pred))
# Puntaje de Varianza. El mejor puntaje es un 1.0
print('Variance score: %.2f' % r2_score(y_train, y_pred))

# Display model parameters
print('Slope = ', regr.coef_)
print('Intercept = ', regr.intercept_)### Step 4: Postprocessing
# Out:
# Coefficients:
#  [5.69765366]
# Independent term:
#  11200.303223074163
# Mean squared error: 372888728.34
# Variance score: 0.06
# Slope =  [5.69765366]
# Intercept =  11200.303223074163

# %% [markdown]
# ## Visualizamos la Recta que obtuvimos

# %%
plt.scatter(X_train[:,0], y_train,  c=asignar, s=tamanios[0])
plt.plot(X_train[:,0], y_pred, color='red', linewidth=3)

plt.xlabel('Cantidad de Palabras')
plt.ylabel('Compartido en Redes')
plt.title('Regresión Lineal')

plt.show()

# %% [markdown]
# ### Predicción 1

# %%
#Vamos a comprobar:
# Quiero predecir cuántos "Shares" voy a obtener por un artículo con 2.000 palabras,
# según nuestro modelo, hacemos:
y_Dosmil = regr.predict([[1742]]) #1888-->200000, 1742-->25000, 761-->21000
print(int(y_Dosmil[0]))
# Out:
# 21125

# %% [markdown]
# Evidentemente No es tan sencillo...
#
# Vamos a mejorar un poco el modelo
#
# # Regresión Lineal Múltiples (múltiples variables)

# %%
#Vamos a intentar mejorar el Modelo, con una dimensión más: 
# Para poder graficar en 3D, haremos una variable nueva que será la suma de los enlaces, comentarios e imágenes
suma = (filtered_data["# of Links"] + filtered_data['# of comments'].fillna(0) + filtered_data['# Images video'])

dataX2 =  pd.DataFrame()
dataX2["Word count"] = filtered_data["Word count"]
dataX2["suma"] = suma
XY_train = np.array(dataX2)
z_train = filtered_data['# Shares'].values

# %% [markdown]
# Atención: Esta vez, nuestras dimensiones de entrenamiento serán X e Y y las etiquetas de predicción serán z.

# %%
# Creamos un nuevo objeto de Regresión Lineal
regr2 = linear_model.LinearRegression()

# Entrenamos el modelo, esta vez, con 2 dimensiones
# obtendremos 2 coeficientes, para graficar un plano
regr2.fit(XY_train, z_train)

# Hacemos la predicción con la que tendremos puntos sobre el plano hallado
z_pred = regr2.predict(XY_train)

# Los coeficientes
print('Coefficients: \n', regr2.coef_)
# Error cuadrático medio
print("Mean squared error: %.2f" % mean_squared_error(z_train, z_pred))
# Evaluamos el puntaje de varianza (siendo 1.0 el mejor posible)
print('Variance score: %.2f' % r2_score(z_train, z_pred))
print('Intercept = ', regr2.intercept_)### Step 4: Postprocessing
# Out:
# Coefficients:
#  [   6.63216324 -483.40753769]
# Mean squared error: 352122816.48
# Variance score: 0.11
# Intercept =  16921.89109834336

# %% [markdown]
# ## Esta vez visualizamos un plano

# %%
X = XY_train
y = z_train
y_pred2 = z_pred

# X tiene dos columnas: X[:, 0] y X[:, 1]
x1 = X[:, 0]
x2 = X[:, 1]

# Crear figura 3D
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Graficar puntos reales
ax.scatter(x1, x2, y, color='blue', label='Datos reales')

# Superficie de predicción (predicción sobre una grilla es más suave, pero esto sirve)
ax.plot_trisurf(x1, x2, y_pred2, alpha=0.5, color='red', label='Plano de predicción')

# Etiquetas
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Target')
ax.set_title('Regresión 3D: datos reales y predicción')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Predicción 2

# %%
# Si quiero predecir cuántos "Shares" voy a obtener por un artículo con: 
# 2000 palabras y con enlaces: 10, comentarios: 4, imagenes: 6
# según nuestro modelo, hacemos:

z_Dosmil = regr2.predict([[1888, 0+0+1]]) #1888-->200000, 1742-->25000, 761-->21000
print(int(z_Dosmil[0]))
# Out:
# 28960

# %% [markdown]
# ## Comparemos las predicciónes obtenidas en los modelos

# %% [markdown]
# En este caso, Obtuvimos mejora en el modelo de 2 dimensiones

# %%
# Restamos los errores calculados antes:
# Obviamente, "menos error" es mejor
mejoraEnError = mean_squared_error(y_train, y_pred) - mean_squared_error(z_train, z_pred)
print(mejoraEnError)
# Out:
# 20765911.860715985

# %%
# También calculamos la mejora en la varianza:
mejoraEnVarianza = r2_score(z_train, z_pred) - r2_score(y_train, y_pred)
print(mejoraEnVarianza)
# Aunque no parezca mucho, recordemos que el valor más alto que se puede obtener es 1.0
# Out:
# 0.052615337462582956

# %%
# Finalmente, mejoramos en nuestra predicción de un artículo de 2.000 palabras, 
# pues aunque disminuyen los "Shares" que obtendremos en el 2do modelo, 
# seguramente será un valor más cercano a la realidad
diferenciaComparir = z_Dosmil - y_Dosmil
print(int(diferenciaComparir[0]))
# Out:
# 7834

# %% [markdown]
# ## ¿Qué conclusiones puedes generar de este ejercicio?
#
# ¿Qué ocurrió con el segundo modelo?
#
# ¿Por qué mejoró la predicción?

# %% [markdown]
# ## Visualizamos como se comporta el error en entrenamiento y prueba si dividimos los datos

# %%
# Division de datos en entrenamiento y pruebas para eliminar el sobreajuste 
# Visualizar las curvas de errores
from sklearn.linear_model import SGDRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
import copy

# Crear datos
X = XY_train
y = z_train

X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=42)

# Parámetros
n_epochs = 100
train_errors = []
test_errors = []
best_model = None
best_test_error = np.inf  # Inicialmente infinito

# Inicializar modelo SGD (warm_start=True para entrenamiento incremental)
model = SGDRegressor(max_iter=1, tol=None, learning_rate='adaptive', eta0=0.009, warm_start=True, random_state=42)
# Entrenamiento manual por iteraciones
for epoch in range(n_epochs):
    model.fit(X_train2, y_train2)

    # Predecir y calcular errores
    y_train_pred = model.predict(X_train2)
    y_test_pred = model.predict(X_test2)
    train_mse = mean_squared_error(y_train2, y_train_pred)
    test_mse = mean_squared_error(y_test2, y_test_pred)

    train_errors.append(train_mse)
    test_errors.append(test_mse)
    
    # Guardar el mejor modelo (menor error de prueba)
    if test_mse < best_test_error:
        best_test_error = test_mse
        best_model = copy.deepcopy(model)  # Importante: copiar el modelo actual


# Graficar errores por iteración
plt.figure(figsize=(6, 4))
plt.plot(range(1, n_epochs + 1), train_errors, label="Error de entrenamiento", color="red")
plt.plot(range(1, n_epochs + 1), test_errors, label="Error de prueba", color="blue")
plt.axhline(best_test_error, color='green', linestyle='--', label='Mejor MSE')
plt.xlabel("Iteración (época)")
plt.ylabel("MSE")
plt.title("Error por Iteración")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
XG = X_test2
yG = y_test2
y_pred3 = best_model.predict(XG)

# X tiene dos columnas: X[:, 0] y X[:, 1]
x1 = XG[:, 0]
x2 = XG[:, 1]

# Crear figura 3D
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Graficar puntos reales
ax.scatter(x1, x2, yG, color='blue', label='Datos reales')

# Superficie de predicción (predicción sobre una grilla es más suave, pero esto sirve)
ax.plot_trisurf(x1, x2, y_pred3, alpha=0.5, color='red', label='Plano de predicción')

# Etiquetas
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Target')
ax.set_title('Regresión 3D: datos reales y predicción')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\m_mir\anaconda3\Lib\site-packages\matplotlib\tri\_triangulation.py:181: RuntimeWarning: invalid value encountered in cast
#   triangles = np.asarray(triangles, dtype=np.int32)

# %% [markdown]
# ### Predicción 3

# %%
z_Dosmil2 = best_model.predict([[761, 0+0+1]]) #1888-->200000, 1742-->25000, 761-->21000
print(int(z_Dosmil2[0]))
# Out:
# 15101286461068062

# %% [markdown]
# ## ¿Qué conclusiones finales puedes tener?
#
# ¿Qué ocurrió con el tercer modelo?
#
# ¿Por qué empeoró la predicción?,¿Cómo podríamos mejorar?

# %% [markdown]
# ### Optimización

# %%
data.head(10)
# Out:
#                                                Title  \
# 0  What is Machine Learning and how do we use it ...
# 1   10 Companies Using Machine Learning in Cool Ways
# 2  How Artificial Intelligence Is Revolutionizing...
# 3  Dbrain and the Blockchain of Artificial Intell...
# 4  Nasa finds entire solar system filled with eig...
# 5  5 ways Data Science and Machine Learning impac...
# 6  200 universities just launched 600 free online...
# 7  How Machine Learning can help Cryptocurrency T...
# 8  Tech companies should stop pretending AI won’t...
# 9  Artificial intelligence is going to completely...
#
#                                                  url  Word count  # of Links  \
# 0  https://blog.signals.network/what-is-machine-l...        1888           1
# 1                                                NaN        1742           9
# 2                                                NaN         962           6
# 3                                                NaN        1221           3
# 4                                                NaN        2039           1
# 5                                                NaN         761           0
# 6  https://qz.com/1120344/200-universities-just-l...        6462         600
# 7  https://cryptovest.com/news/how-machine-learni...         753           3
# 8  https://www.technologyreview.com/s/610298/tech...        1118           2
# 9                                                NaN        1581           4
#
#    # of comments  # Images video  Elapsed days  # Shares
# 0            2.0               2            34    200000
# 1            NaN               9             5     25000
# 2            0.0               1            10     42000
# 3            NaN               2            68    200000
# 4          104.0               4           131    200000
# 5            NaN               1            14     21000
# 6           28.0               2           170    200000
# 7            0.0               1            78     77000
# 8            NaN               1            62     59400
# 9            NaN               2            60     35000

# %%
dataframe_intermedio = data.drop(['Title','url'] ,axis=1)
dataframe_intermedio.head(10)
# Out:
#    Word count  # of Links  # of comments  # Images video  Elapsed days  \
# 0        1888           1            2.0               2            34
# 1        1742           9            NaN               9             5
# 2         962           6            0.0               1            10
# 3        1221           3            NaN               2            68
# 4        2039           1          104.0               4           131
# 5         761           0            NaN               1            14
# 6        6462         600           28.0               2           170
# 7         753           3            0.0               1            78
# 8        1118           2            NaN               1            62
# 9        1581           4            NaN               2            60
#
#    # Shares
# 0    200000
# 1     25000
# 2     42000
# 3    200000
# 4    200000
# 5     21000
# 6    200000
# 7     77000
# 8     59400
# 9     35000

# %%
print(dataframe_intermedio.isnull().sum())
# Out:
# Word count         0
# # of Links         0
# # of comments     32
# # Images video     0
# Elapsed days       0
# # Shares           0
# dtype: int64

# %%
dataframe_intermedio.corr().style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_1865a_row0_col0, #T_1865a_row1_col1, #T_1865a_row2_col2, #T_1865a_row3_col3, #T_1865a_row4_col4, #T_1865a_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1865a_row0_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_1865a_row0_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_1865a_row0_col3 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_1865a_row0_col4, #T_1865a_row1_col3, #T_1865a_row2_col3, #T_1865a_row3_col1, #T_1865a_row3_col2, #T_1865a_row3_col5, #T_1865a_row4_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1865a_row0_col5 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_1865a_row1_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_1865a_row1_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_1865a_row1_col4, #T_1865a_row4_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_1865a_row1_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_1865a_row2_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_1865a_row2_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_1865a_row2_col4 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_1865a_row2_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_1865a_row3_col0 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_1865a_row3_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_1865a_row4_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_1865a_row4_col2, #T_1865a_row5_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_1865a_row4_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_1865a_row5_col1 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_1865a_row5_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_1865a_row5_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_1865a_row5_col4 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# </style>
# <table id="T_1865a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1865a_level0_col0" class="col_heading level0 col0" >Word count</th>
#       <th id="T_1865a_level0_col1" class="col_heading level0 col1" ># of Links</th>
#       <th id="T_1865a_level0_col2" class="col_heading level0 col2" ># of comments</th>
#       <th id="T_1865a_level0_col3" class="col_heading level0 col3" ># Images video</th>
#       <th id="T_1865a_level0_col4" class="col_heading level0 col4" >Elapsed days</th>
#       <th id="T_1865a_level0_col5" class="col_heading level0 col5" ># Shares</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1865a_level0_row0" class="row_heading level0 row0" >Word count</th>
#       <td id="T_1865a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_1865a_row0_col1" class="data row0 col1" >0.346730</td>
#       <td id="T_1865a_row0_col2" class="data row0 col2" >0.108730</td>
#       <td id="T_1865a_row0_col3" class="data row0 col3" >0.463767</td>
#       <td id="T_1865a_row0_col4" class="data row0 col4" >-0.167361</td>
#       <td id="T_1865a_row0_col5" class="data row0 col5" >0.141736</td>
#     </tr>
#     <tr>
#       <th id="T_1865a_level0_row1" class="row_heading level0 row1" ># of Links</th>
#       <td id="T_1865a_row1_col0" class="data row1 col0" >0.346730</td>
#       <td id="T_1865a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_1865a_row1_col2" class="data row1 col2" >0.116415</td>
#       <td id="T_1865a_row1_col3" class="data row1 col3" >0.021087</td>
#       <td id="T_1865a_row1_col4" class="data row1 col4" >0.059157</td>
#       <td id="T_1865a_row1_col5" class="data row1 col5" >0.288325</td>
#     </tr>
#     <tr>
#       <th id="T_1865a_level0_row2" class="row_heading level0 row2" ># of comments</th>
#       <td id="T_1865a_row2_col0" class="data row2 col0" >0.108730</td>
#       <td id="T_1865a_row2_col1" class="data row2 col1" >0.116415</td>
#       <td id="T_1865a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_1865a_row2_col3" class="data row2 col3" >0.018377</td>
#       <td id="T_1865a_row2_col4" class="data row2 col4" >0.279116</td>
#       <td id="T_1865a_row2_col5" class="data row2 col5" >0.437413</td>
#     </tr>
#     <tr>
#       <th id="T_1865a_level0_row3" class="row_heading level0 row3" ># Images video</th>
#       <td id="T_1865a_row3_col0" class="data row3 col0" >0.463767</td>
#       <td id="T_1865a_row3_col1" class="data row3 col1" >0.021087</td>
#       <td id="T_1865a_row3_col2" class="data row3 col2" >0.018377</td>
#       <td id="T_1865a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_1865a_row3_col4" class="data row3 col4" >0.209958</td>
#       <td id="T_1865a_row3_col5" class="data row3 col5" >0.062170</td>
#     </tr>
#     <tr>
#       <th id="T_1865a_level0_row4" class="row_heading level0 row4" >Elapsed days</th>
#       <td id="T_1865a_row4_col0" class="data row4 col0" >-0.167361</td>
#       <td id="T_1865a_row4_col1" class="data row4 col1" >0.059157</td>
#       <td id="T_1865a_row4_col2" class="data row4 col2" >0.279116</td>
#       <td id="T_1865a_row4_col3" class="data row4 col3" >0.209958</td>
#       <td id="T_1865a_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_1865a_row4_col5" class="data row4 col5" >0.325343</td>
#     </tr>
#     <tr>
#       <th id="T_1865a_level0_row5" class="row_heading level0 row5" ># Shares</th>
#       <td id="T_1865a_row5_col0" class="data row5 col0" >0.141736</td>
#       <td id="T_1865a_row5_col1" class="data row5 col1" >0.288325</td>
#       <td id="T_1865a_row5_col2" class="data row5 col2" >0.437413</td>
#       <td id="T_1865a_row5_col3" class="data row5 col3" >0.062170</td>
#       <td id="T_1865a_row5_col4" class="data row5 col4" >0.325343</td>
#       <td id="T_1865a_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Visualizar los datos de entrada
colores=['orange','blue']
tamanios=[30,60]

f1 = dataframe_intermedio['Elapsed days'].values
f2 = dataframe_intermedio['# Shares'].values
plt.figure(figsize=(8, 6))
# Vamos a pintar en 2 colores los puntos por debajo de la media de Cantidad de Palabras
asignar=[]
for index, row in data.iterrows():
    if(row['Elapsed days']>98):
        asignar.append(colores[0])
    else:
        asignar.append(colores[1])
    
plt.scatter(f1, f2, c=asignar, s=tamanios[0])
plt.show()

# %%
#Visualizar los datos de entrada
colores=['orange','blue']
tamanios=[30,60]
plt.figure(figsize=(8, 6))
f1 = dataframe_intermedio['# of Links'].values
f2 = dataframe_intermedio['# Shares'].values

# Vamos a pintar en 2 colores los puntos por debajo de la media de Cantidad de Palabras
asignar=[]
for index, row in data.iterrows():
    if(row['# of Links']>10):
        asignar.append(colores[0])
    else:
        asignar.append(colores[1])
    
plt.scatter(f1, f2, c=asignar, s=tamanios[0])
plt.show()

# %%
dataframe_intermedio['# of comments'] = dataframe_intermedio['# of comments'].fillna(0)

# %%
#Visualizar los datos de entrada
colores=['orange','blue']
tamanios=[30,60]
plt.figure(figsize=(8, 6))
f1 = dataframe_intermedio['# of comments'].values
f2 = dataframe_intermedio['# Shares'].values

# Vamos a pintar en 2 colores los puntos por debajo de la media de Cantidad de Palabras
asignar=[]
for index, row in data.iterrows():
    if(row['# of comments']>9):
        asignar.append(colores[0])
    else:
        asignar.append(colores[1])
    
plt.scatter(f1, f2, c=asignar, s=tamanios[0])
plt.show()

# %%
dataframe_fin = dataframe_intermedio[(data['# Shares'] <= 100000)]
#print(dataframe_fin.shape)
#dataframe_fin = dataframe_intermedio.copy()
#print(dataframe_fin.shape)

# %%
dataframe_fin.tail(10)
# Out:
#      Word count  # of Links  # of comments  # Images video  Elapsed days  \
# 151        1443           7            8.0               1            79
# 152         912           5           14.0               6            80
# 153        2366           2           12.0               1            81
# 154        1542           6            1.0               6            82
# 155        1201           1            0.0               1            83
# 156        3239           3           11.0               1            84
# 157        2566           3            8.0               4            85
# 158        2089           4            4.0               1            86
# 159        1530           4           12.0               3            87
# 160         953           6           13.0               2            88
#
#      # Shares
# 151      3968
# 152      1824
# 153      2958
# 154     22359
# 155      8707
# 156      3239
# 157     25019
# 158     49614
# 159     33660
# 160      5956

# %%
dataframe_fin.corr().style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_05d71_row0_col0, #T_05d71_row1_col1, #T_05d71_row2_col2, #T_05d71_row3_col3, #T_05d71_row4_col4, #T_05d71_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_05d71_row0_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_05d71_row0_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_05d71_row0_col3 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_05d71_row0_col4, #T_05d71_row1_col2, #T_05d71_row1_col5, #T_05d71_row4_col0, #T_05d71_row5_col1, #T_05d71_row5_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_05d71_row0_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_05d71_row1_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_05d71_row1_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_05d71_row1_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_05d71_row2_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_05d71_row2_col1, #T_05d71_row3_col5, #T_05d71_row5_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_05d71_row2_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_05d71_row2_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_05d71_row2_col5 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_05d71_row3_col0 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_05d71_row3_col1 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_05d71_row3_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_05d71_row3_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_05d71_row4_col1 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_05d71_row4_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_05d71_row4_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_05d71_row4_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_05d71_row5_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_05d71_row5_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# </style>
# <table id="T_05d71">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05d71_level0_col0" class="col_heading level0 col0" >Word count</th>
#       <th id="T_05d71_level0_col1" class="col_heading level0 col1" ># of Links</th>
#       <th id="T_05d71_level0_col2" class="col_heading level0 col2" ># of comments</th>
#       <th id="T_05d71_level0_col3" class="col_heading level0 col3" ># Images video</th>
#       <th id="T_05d71_level0_col4" class="col_heading level0 col4" >Elapsed days</th>
#       <th id="T_05d71_level0_col5" class="col_heading level0 col5" ># Shares</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05d71_level0_row0" class="row_heading level0 row0" >Word count</th>
#       <td id="T_05d71_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_05d71_row0_col1" class="data row0 col1" >0.202585</td>
#       <td id="T_05d71_row0_col2" class="data row0 col2" >0.070775</td>
#       <td id="T_05d71_row0_col3" class="data row0 col3" >0.536216</td>
#       <td id="T_05d71_row0_col4" class="data row0 col4" >-0.211242</td>
#       <td id="T_05d71_row0_col5" class="data row0 col5" >0.156441</td>
#     </tr>
#     <tr>
#       <th id="T_05d71_level0_row1" class="row_heading level0 row1" ># of Links</th>
#       <td id="T_05d71_row1_col0" class="data row1 col0" >0.202585</td>
#       <td id="T_05d71_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_05d71_row1_col2" class="data row1 col2" >-0.124430</td>
#       <td id="T_05d71_row1_col3" class="data row1 col3" >0.448648</td>
#       <td id="T_05d71_row1_col4" class="data row1 col4" >0.109161</td>
#       <td id="T_05d71_row1_col5" class="data row1 col5" >-0.201309</td>
#     </tr>
#     <tr>
#       <th id="T_05d71_level0_row2" class="row_heading level0 row2" ># of comments</th>
#       <td id="T_05d71_row2_col0" class="data row2 col0" >0.070775</td>
#       <td id="T_05d71_row2_col1" class="data row2 col1" >-0.124430</td>
#       <td id="T_05d71_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_05d71_row2_col3" class="data row2 col3" >-0.032739</td>
#       <td id="T_05d71_row2_col4" class="data row2 col4" >0.067629</td>
#       <td id="T_05d71_row2_col5" class="data row2 col5" >0.200119</td>
#     </tr>
#     <tr>
#       <th id="T_05d71_level0_row3" class="row_heading level0 row3" ># Images video</th>
#       <td id="T_05d71_row3_col0" class="data row3 col0" >0.536216</td>
#       <td id="T_05d71_row3_col1" class="data row3 col1" >0.448648</td>
#       <td id="T_05d71_row3_col2" class="data row3 col2" >-0.032739</td>
#       <td id="T_05d71_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_05d71_row3_col4" class="data row3 col4" >0.060024</td>
#       <td id="T_05d71_row3_col5" class="data row3 col5" >-0.125529</td>
#     </tr>
#     <tr>
#       <th id="T_05d71_level0_row4" class="row_heading level0 row4" >Elapsed days</th>
#       <td id="T_05d71_row4_col0" class="data row4 col0" >-0.211242</td>
#       <td id="T_05d71_row4_col1" class="data row4 col1" >0.109161</td>
#       <td id="T_05d71_row4_col2" class="data row4 col2" >0.067629</td>
#       <td id="T_05d71_row4_col3" class="data row4 col3" >0.060024</td>
#       <td id="T_05d71_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_05d71_row4_col5" class="data row4 col5" >-0.133702</td>
#     </tr>
#     <tr>
#       <th id="T_05d71_level0_row5" class="row_heading level0 row5" ># Shares</th>
#       <td id="T_05d71_row5_col0" class="data row5 col0" >0.156441</td>
#       <td id="T_05d71_row5_col1" class="data row5 col1" >-0.201309</td>
#       <td id="T_05d71_row5_col2" class="data row5 col2" >0.200119</td>
#       <td id="T_05d71_row5_col3" class="data row5 col3" >-0.125529</td>
#       <td id="T_05d71_row5_col4" class="data row5 col4" >-0.133702</td>
#       <td id="T_05d71_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Opcionalmente podemos formar un feature
suma = (dataframe_fin["# of Links"] + dataframe_fin['# of comments'] + dataframe_fin['# Images video'])
#suma = (dataframe_fin["Word count"]/dataframe_fin['# Images video'])
dataX3 =  pd.DataFrame()
dataX3["Word count"] = dataframe_fin["Word count"]
#dataX3["# of Links"] = dataframe_fin["# of Links"]
#dataX3['# of comments'] = dataframe_fin['# of comments']
#dataX3['Elapsed days'] = dataframe_fin['Elapsed days']
dataX3["suma"] = suma
dataX3["# Shares"] = dataframe_fin["# Shares"]
dataX3.corr().style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_64d32_row0_col0, #T_64d32_row1_col1, #T_64d32_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_64d32_row0_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_64d32_row0_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_64d32_row1_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_64d32_row1_col2, #T_64d32_row2_col0, #T_64d32_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_64d32">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64d32_level0_col0" class="col_heading level0 col0" >Word count</th>
#       <th id="T_64d32_level0_col1" class="col_heading level0 col1" >suma</th>
#       <th id="T_64d32_level0_col2" class="col_heading level0 col2" ># Shares</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64d32_level0_row0" class="row_heading level0 row0" >Word count</th>
#       <td id="T_64d32_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_64d32_row0_col1" class="data row0 col1" >0.313311</td>
#       <td id="T_64d32_row0_col2" class="data row0 col2" >0.156441</td>
#     </tr>
#     <tr>
#       <th id="T_64d32_level0_row1" class="row_heading level0 row1" >suma</th>
#       <td id="T_64d32_row1_col0" class="data row1 col0" >0.313311</td>
#       <td id="T_64d32_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_64d32_row1_col2" class="data row1 col2" >0.011863</td>
#     </tr>
#     <tr>
#       <th id="T_64d32_level0_row2" class="row_heading level0 row2" ># Shares</th>
#       <td id="T_64d32_row2_col0" class="data row2 col0" >0.156441</td>
#       <td id="T_64d32_row2_col1" class="data row2 col1" >0.011863</td>
#       <td id="T_64d32_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Copiamos el feature al dataframe final que utilizaremos
dataframe_fin = dataX3.copy()

# %%
Xopt = dataframe_fin.drop(['# Shares'], axis=1)
Yopt = dataframe_fin['# Shares'].copy()

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = MinMaxScaler()
scaler.fit(Xopt)
Xoptscaler = scaler.transform(Xopt)

# %%
# Crear datos
Xop = Xoptscaler
yop = Yopt

X_train2, X_test2, y_train2, y_test2 = train_test_split(Xop, yop, test_size=0.2, shuffle=True, random_state=42)

# Parámetros
n_epochs = 1000
train_errors_opt = []
test_errors_opt = []
best_model_opt = None
best_test_opt_error = np.inf  # Inicialmente infinito

# Inicializar modelo SGD (warm_start=True para entrenamiento incremental)
model_opt = SGDRegressor(max_iter=1, tol=None, learning_rate='constant', eta0=0.0009, warm_start=True, random_state=42)
# Entrenamiento manual por iteraciones
for epoch in range(n_epochs):
    model_opt.fit(X_train2, y_train2)

    # Predecir y calcular errores
    y_train_pred = model_opt.predict(X_train2)
    y_test_pred = model_opt.predict(X_test2)
    train_mse = mean_squared_error(y_train2, y_train_pred)
    test_mse = mean_squared_error(y_test2, y_test_pred)

    train_errors_opt.append(train_mse)
    test_errors_opt.append(test_mse)
    
    # Guardar el mejor modelo (menor error de prueba)
    if test_mse < best_test_opt_error:
        best_test_opt_error = test_mse
        best_model_opt = copy.deepcopy(model_opt)  # Importante: copiar el modelo actual


# Graficar errores por iteración
plt.figure(figsize=(6, 4))
plt.plot(range(1, n_epochs + 1), train_errors_opt, label="Error de entrenamiento", color="red")
plt.plot(range(1, n_epochs + 1), test_errors_opt, label="Error de prueba", color="blue")
plt.axhline(best_test_opt_error, color='green', linestyle='--', label='Mejor MSE')
plt.xlabel("Iteración (época)")
plt.ylabel("MSE")
plt.title("Error por Iteración")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
z_Dosmil3 = best_model_opt.predict(scaler.transform([[1201, 1, 1, 9, 83]]))
print(int(z_Dosmil3[0]))

#1201	1	0.0	1	83	8707
#3239	3	11.0	1	84	3239
#2566	3	8.0	4	85	25019
# Out:
# 16046
# C:\Users\m_mir\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# Creamos un nuevo objeto de Regresión Lineal
regr4 = linear_model.LinearRegression()

# Entrenamos el modelo, esta vez, con 2 dimensiones
# obtendremos 2 coeficientes, para graficar un plano
regr4.fit(X_train2, y_train2)

# Hacemos la predicción con la que tendremos puntos sobre el plano hallado
z_pred4 = regr4.predict(X_test2)

# Los coeficientes
print('Coefficients: \n', regr4.coef_)
# Error cuadrático medio
print("Mean squared error: %.2f" % mean_squared_error(y_test2, z_pred4))
# Evaluamos el puntaje de varianza (siendo 1.0 el mejor posible)
print('Variance score: %.2f' % r2_score(y_test2, z_pred4))
print('Intercept = ', regr4.intercept_)### Step 4: Postprocessing
# Out:
# Coefficients:
#  [ 32925.95560891 -19260.12343668  37364.34186404 -24151.32622212
#   -7813.60211253]
# Mean squared error: 426196439.06
# Variance score: 0.13
# Intercept =  20050.626073411564

# %%
z_Dosmil4 = regr4.predict(scaler.transform([[1201, 1, 9, 1, 83]]))
print(int(z_Dosmil4[0]))

#1201	1	0.0	1	83	8707
#3239	3	11.0	1	84	3239
#2566	3	8.0	4	85	25019
# Out:
# 25197
# C:\Users\m_mir\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
